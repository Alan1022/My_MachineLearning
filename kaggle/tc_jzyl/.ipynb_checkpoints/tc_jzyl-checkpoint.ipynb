# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
# load data
train = pd.read_csv('/Users/alan/Downloads/github/kaggle/tc_jzyl/d_train_20180102.csv',encoding='gbk')
test = pd.read_csv('/Users/alan/Downloads/github/kaggle/tc_jzyl/d_test_A_20180102.csv',encoding='gbk')

# %%
train.shape,test.shape
# Out:
# ((5642, 42), (1000, 41))

# %%
train.columns
# Out:
# Index(['id', '性别', '年龄', '体检日期', '*天门冬氨酸氨基转换酶', '*丙氨酸氨基转换酶', '*碱性磷酸酶',
#        '*r-谷氨酰基转换酶', '*总蛋白', '白蛋白', '*球蛋白', '白球比例', '甘油三酯', '总胆固醇',
#        '高密度脂蛋白胆固醇', '低密度脂蛋白胆固醇', '尿素', '肌酐', '尿酸', '乙肝表面抗原', '乙肝表面抗体', '乙肝e抗原',
#        '乙肝e抗体', '乙肝核心抗体', '白细胞计数', '红细胞计数', '血红蛋白', '红细胞压积', '红细胞平均体积',
#        '红细胞平均血红蛋白量', '红细胞平均血红蛋白浓度', '红细胞体积分布宽度', '血小板计数', '血小板平均体积',
#        '血小板体积分布宽度', '血小板比积', '中性粒细胞%', '淋巴细胞%', '单核细胞%', '嗜酸细胞%', '嗜碱细胞%',
#        '血糖'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['id', '性别', '年龄', '体检日期', '*天门冬氨酸氨基转换酶', '*丙氨酸氨基转换酶', '*碱性磷酸酶',
#        '*r-谷氨酰基转换酶', '*总蛋白', '白蛋白', '*球蛋白', '白球比例', '甘油三酯', '总胆固醇',
#        '高密度脂蛋白胆固醇', '低密度脂蛋白胆固醇', '尿素', '肌酐', '尿酸', '乙肝表面抗原', '乙肝表面抗体', '乙肝e抗原',
#        '乙肝e抗体', '乙肝核心抗体', '白细胞计数', '红细胞计数', '血红蛋白', '红细胞压积', '红细胞平均体积',
#        '红细胞平均血红蛋白量', '红细胞平均血红蛋白浓度', '红细胞体积分布宽度', '血小板计数', '血小板平均体积',
#        '血小板体积分布宽度', '血小板比积', '中性粒细胞%', '淋巴细胞%', '单核细胞%', '嗜酸细胞%', '嗜碱细胞%'],
#       dtype='object')

# %%
#合并数据，一起预处理
train['source'] = 'train'
test['source'] = 'test'
data = pd.concat([train,test],axis = 0,ignore_index = True)  #axis=0纵向合并，类似行合并，insert操作；ignore_index = True 行索引重新排序

# %%
data.shape
# Out:
# (6642, 43)

# %%
data.columns
# Out:
# Index(['*r-谷氨酰基转换酶', '*丙氨酸氨基转换酶', '*天门冬氨酸氨基转换酶', '*总蛋白', '*球蛋白', '*碱性磷酸酶',
#        'id', 'source', '中性粒细胞%', '乙肝e抗体', '乙肝e抗原', '乙肝核心抗体', '乙肝表面抗体',
#        '乙肝表面抗原', '低密度脂蛋白胆固醇', '体检日期', '单核细胞%', '嗜碱细胞%', '嗜酸细胞%', '尿素', '尿酸',
#        '年龄', '性别', '总胆固醇', '淋巴细胞%', '甘油三酯', '白球比例', '白细胞计数', '白蛋白',
#        '红细胞体积分布宽度', '红细胞压积', '红细胞平均体积', '红细胞平均血红蛋白浓度', '红细胞平均血红蛋白量', '红细胞计数',
#        '肌酐', '血小板体积分布宽度', '血小板平均体积', '血小板比积', '血小板计数', '血糖', '血红蛋白',
#        '高密度脂蛋白胆固醇'],
#       dtype='object')

# %%
data.tail(10)
# Out:
#       *r-谷氨酰基转换酶  *丙氨酸氨基转换酶  *天门冬氨酸氨基转换酶   *总蛋白   *球蛋白  *碱性磷酸酶    id source  \
# 6632       22.79      24.59        22.83  77.88  32.45   87.93  6759   test
# 6633       18.72      14.51        20.83  80.52  31.67   61.61  6760   test
# 6634       15.57      10.70        13.65  75.17  29.03   72.94  6761   test
# 6635       30.07      47.61        35.86  77.00  33.12   67.46  6762   test
# 6636       28.20      38.47        30.47  78.42  31.83  132.95  6763   test
# 6637         NaN        NaN          NaN    NaN    NaN     NaN  6764   test
# 6638       37.05      12.46        19.33  76.14  33.99  146.11  6765   test
# 6639       27.82      13.24        18.50  80.06  31.90   72.54  6766   test
# 6640       20.80       7.08        26.15  75.05  31.05   67.68  6767   test
# 6641         NaN        NaN          NaN    NaN    NaN     NaN  6768   test
#
#       中性粒细胞%  乙肝e抗体    ...      红细胞平均血红蛋白量  红细胞计数      肌酐  血小板体积分布宽度  血小板平均体积  \
# ...

# %%
# train.dtypes
data.dtypes[data.dtypes == np.object]
# Out:
# source    object
# 体检日期      object
# 性别        object
# dtype: object

# %%
data['性别'].unique()
# Out:
# array(['男', '女', '??'], dtype=object)

# %%
data['性别'].value_counts()
# Out:
# 男     3328
# 女     3313
# ??       1
# Name: 性别, dtype: int64

# %%
data['性别'] = data['性别'].replace(['男','女','??'],[1,0,1])

# %%
data['性别'].value_counts()
# Out:
# 1    3329
# 0    3313
# Name: 性别, dtype: int64

# %%
data['体检日期'].unique()
# Out:
# array(['12/10/2017', '19/10/2017', '26/10/2017', '25/10/2017',
#        '18/10/2017', '21/09/2017', '16/10/2017', '10/10/2017',
#        '13/10/2017', '11/10/2017', '27/09/2017', '28/09/2017',
#        '24/10/2017', '30/10/2017', '29/09/2017', '30/09/2017',
#        '20/10/2017', '31/10/2017', '17/10/2017', '27/10/2017',
#        '23/10/2017', '25/09/2017', '22/09/2017', '26/09/2017',
#        '09/10/2017', '15/09/2017', '20/09/2017', '19/09/2017',
#        '18/09/2017', '24/09/2017'], dtype=object)

# %%
import datetime
import time
year=''
month=''
day=''
data['体检天数']=''
tjdays=[]
now=datetime.datetime(2018,1,1)
for date in data['体检日期']:
    day,month,year=date.strip().split('/')
    year = int(year)
    month = int(month)
    day = int(day)
    tjdate = datetime.datetime(year,month,day)
    days=(now - tjdate).days
    tjdays.append(days)
tjdt = np.array(tjdays)  
data['体检天数']=tjdt
data['体检天数']
# Out:
# 0        81
# 1        74
# 2        67
# 3        68
# 4        67
# 5        75
# 6       102
# 7       102
# 8        77
# 9        83
# 10       80
# 11       83
# 12       74
# 13       82
# 14       96
# 15       95
# 16       69
# 17       77
# 18       63
# 19       95
# 20       94
# 21       67
# 22       74
# 23       93
# 24       73
# 25       63
# 26       63
# 27       62
# 28       69
# 29       76
#        ...
# 6612     73
# 6613     73
# 6614     73
# 6615     73
# 6616     73
# 6617     73
# 6618     73
# 6619     73
# 6620     73
# 6621     73
# 6622     73
# 6623     73
# 6624     73
# 6625     73
# 6626     73
# 6627     73
# 6628     73
# 6629     73
# 6630     73
# 6631     73
# 6632     73
# 6633     73
# 6634     73
# 6635     73
# 6636     73
# 6637     73
# 6638     73
# 6639     73
# 6640     73
# 6641     73
# Name: 体检天数, Length: 6642, dtype: int64

# %%
data.drop('体检日期',axis=1,inplace=True)

# %%
data.dtypes
# Out:
# *r-谷氨酰基转换酶     float64
# *丙氨酸氨基转换酶      float64
# *天门冬氨酸氨基转换酶    float64
# *总蛋白           float64
# *球蛋白           float64
# *碱性磷酸酶         float64
# id               int64
# source          object
# 中性粒细胞%         float64
# 乙肝e抗体          float64
# 乙肝e抗原          float64
# 乙肝核心抗体         float64
# 乙肝表面抗体         float64
# 乙肝表面抗原         float64
# 低密度脂蛋白胆固醇      float64
# 单核细胞%          float64
# 嗜碱细胞%          float64
# 嗜酸细胞%          float64
# 尿素             float64
# 尿酸             float64
# 年龄               int64
# 性别               int64
# 总胆固醇           float64
# 淋巴细胞%          float64
# 甘油三酯           float64
# 白球比例           float64
# 白细胞计数          float64
# 白蛋白            float64
# 红细胞体积分布宽度      float64
# 红细胞压积          float64
# 红细胞平均体积        float64
# 红细胞平均血红蛋白浓度    float64
# 红细胞平均血红蛋白量     float64
# 红细胞计数          float64
# 肌酐             float64
# 血小板体积分布宽度      float64
# 血小板平均体积        float64
# 血小板比积          float64
# 血小板计数          float64
# 血糖             float64
# ...

# %%
data.describe()
# Out:
#         *r-谷氨酰基转换酶    *丙氨酸氨基转换酶  *天门冬氨酸氨基转换酶         *总蛋白         *球蛋白  \
# count  5236.000000  5236.000000  5236.000000  5236.000000  5236.000000
# mean     38.752624    27.587544    26.789091    76.830267    30.971663
# std      41.465209    22.298356    13.199059     4.026034     3.559522
# min       6.360000     0.120000    10.040000    57.320000     7.060000
# 25%      17.777500    15.137500    20.260000    74.230000    28.610000
# 50%      26.135000    21.465000    23.895000    76.670000    30.830000
# 75%      43.612500    32.242500    29.270000    79.600000    33.180000
# max     736.990000   498.890000   434.950000   100.410000    66.180000
#
#             *碱性磷酸酶           id       中性粒细胞%        乙肝e抗体        乙肝e抗原  \
# count  5236.000000  6642.000000  6621.000000  1532.000000  1532.000000
# mean     87.564291  3375.445950    56.739012     1.747572     0.072710
# std      25.604687  1950.668998     7.848217     0.805137     0.506985
# ...

# %%
data_desc = data.describe()

# %%
count_num = data_desc.loc['count',:].max()
recept_nan_num = count_num * 0.3
count_num,recept_nan_num
# Out:
# (6642.0, 1992.5999999999999)

# %%
#将缺失值严重的数据删除掉，并将缺失值可以接受的数据用平均值做空值补缺
for col in data_desc.columns:
    if data_desc.loc['count',col] < recept_nan_num:
        data.drop(col,axis=1,inplace=True)
    if data_desc.loc['count',col] < count_num and data_desc.loc['count',col] >= recept_nan_num:
        data[col] = data[col].fillna(data[col].mean())

# %%
data.dtypes
# Out:
# *r-谷氨酰基转换酶     float64
# *丙氨酸氨基转换酶      float64
# *天门冬氨酸氨基转换酶    float64
# *总蛋白           float64
# *球蛋白           float64
# *碱性磷酸酶         float64
# id               int64
# source          object
# 中性粒细胞%         float64
# 低密度脂蛋白胆固醇      float64
# 单核细胞%          float64
# 嗜碱细胞%          float64
# 嗜酸细胞%          float64
# 尿素             float64
# 尿酸             float64
# 年龄               int64
# 性别               int64
# 总胆固醇           float64
# 淋巴细胞%          float64
# 甘油三酯           float64
# 白球比例           float64
# 白细胞计数          float64
# 白蛋白            float64
# 红细胞体积分布宽度      float64
# 红细胞压积          float64
# 红细胞平均体积        float64
# 红细胞平均血红蛋白浓度    float64
# 红细胞平均血红蛋白量     float64
# 红细胞计数          float64
# 肌酐             float64
# 血小板体积分布宽度      float64
# 血小板平均体积        float64
# 血小板比积          float64
# 血小板计数          float64
# 血糖             float64
# 血红蛋白           float64
# 高密度脂蛋白胆固醇      float64
# 体检天数             int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6642 entries, 0 to 6641
# Data columns (total 38 columns):
# *r-谷氨酰基转换酶     6642 non-null float64
# *丙氨酸氨基转换酶      6642 non-null float64
# *天门冬氨酸氨基转换酶    6642 non-null float64
# *总蛋白           6642 non-null float64
# *球蛋白           6642 non-null float64
# *碱性磷酸酶         6642 non-null float64
# id             6642 non-null int64
# source         6642 non-null object
# 中性粒细胞%         6642 non-null float64
# 低密度脂蛋白胆固醇      6642 non-null float64
# 单核细胞%          6642 non-null float64
# 嗜碱细胞%          6642 non-null float64
# 嗜酸细胞%          6642 non-null float64
# 尿素             6642 non-null float64
# 尿酸             6642 non-null float64
# 年龄             6642 non-null int64
# 性别             6642 non-null int64
# 总胆固醇           6642 non-null float64
# 淋巴细胞%          6642 non-null float64
# 甘油三酯           6642 non-null float64
# 白球比例           6642 non-null float64
# 白细胞计数          6642 non-null float64
# ...

# %%
data.describe()
# Out:
#         *r-谷氨酰基转换酶    *丙氨酸氨基转换酶  *天门冬氨酸氨基转换酶         *总蛋白         *球蛋白  \
# count  6642.000000  6642.000000  6642.000000  6642.000000  6642.000000
# mean     38.752624    27.587544    26.789091    76.830267    30.971663
# std      36.815056    19.797687    11.718839     3.574530     3.160336
# min       6.360000     0.120000    10.040000    57.320000     7.060000
# 25%      19.662500    16.700000    21.210000    74.900000    29.240000
# 50%      33.425000    26.215000    26.440000    76.830267    30.971663
# 75%      38.752624    28.517500    27.507500    78.677500    32.450000
# max     736.990000   498.890000   434.950000   100.410000    66.180000
#
#             *碱性磷酸酶           id       中性粒细胞%    低密度脂蛋白胆固醇        单核细胞%  \
# count  6642.000000  6642.000000  6642.000000  6642.000000  6642.000000
# mean     87.564291  3375.445950    56.739012     3.378736     6.845371
# std      22.733226  1950.668998     7.835798     0.770236     1.556023
# ...

# %%
# 删除高线性相关的特征
# relation = data.corr()
# relation

# %%
# length = relation.shape[0]
# high_corr = list()
# final_cols = []
# del_cols =[]
# for i in range(length):
#     if relation.columns[i] not in del_cols:
#         final_cols.append(relation.columns[i])
#         for j in range(i+1,length):
#             if (relation.iloc[i,j] > 0.98) and (relation.columns[j] not in del_cols):
#                 del_cols.append(relation.columns[j])
# data = data[final_cols]

# %%
data.dtypes
# Out:
# *r-谷氨酰基转换酶     float64
# *丙氨酸氨基转换酶      float64
# *天门冬氨酸氨基转换酶    float64
# *总蛋白           float64
# *球蛋白           float64
# *碱性磷酸酶         float64
# id               int64
# source          object
# 中性粒细胞%         float64
# 低密度脂蛋白胆固醇      float64
# 单核细胞%          float64
# 嗜碱细胞%          float64
# 嗜酸细胞%          float64
# 尿素             float64
# 尿酸             float64
# 年龄               int64
# 性别               int64
# 总胆固醇           float64
# 淋巴细胞%          float64
# 甘油三酯           float64
# 白球比例           float64
# 白细胞计数          float64
# 白蛋白            float64
# 红细胞体积分布宽度      float64
# 红细胞压积          float64
# 红细胞平均体积        float64
# 红细胞平均血红蛋白浓度    float64
# 红细胞平均血红蛋白量     float64
# 红细胞计数          float64
# 肌酐             float64
# 血小板体积分布宽度      float64
# 血小板平均体积        float64
# 血小板比积          float64
# 血小板计数          float64
# 血糖             float64
# 血红蛋白           float64
# 高密度脂蛋白胆固醇      float64
# 体检天数             int64
# dtype: object

# %%
train = data.loc[data['source'] == 'train']
test = data.loc[data['source'] == 'test']

# %%
train.drop('source',axis = 1,inplace = True)
test.drop('source',axis = 1,inplace = True)
# Out:
# /Users/alan/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/alan/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
train.dtypes
# Out:
# *r-谷氨酰基转换酶     float64
# *丙氨酸氨基转换酶      float64
# *天门冬氨酸氨基转换酶    float64
# *总蛋白           float64
# *球蛋白           float64
# *碱性磷酸酶         float64
# id               int64
# 中性粒细胞%         float64
# 低密度脂蛋白胆固醇      float64
# 单核细胞%          float64
# 嗜碱细胞%          float64
# 嗜酸细胞%          float64
# 尿素             float64
# 尿酸             float64
# 年龄               int64
# 性别               int64
# 总胆固醇           float64
# 淋巴细胞%          float64
# 甘油三酯           float64
# 白球比例           float64
# 白细胞计数          float64
# 白蛋白            float64
# 红细胞体积分布宽度      float64
# 红细胞压积          float64
# 红细胞平均体积        float64
# 红细胞平均血红蛋白浓度    float64
# 红细胞平均血红蛋白量     float64
# 红细胞计数          float64
# 肌酐             float64
# 血小板体积分布宽度      float64
# 血小板平均体积        float64
# 血小板比积          float64
# 血小板计数          float64
# 血糖             float64
# 血红蛋白           float64
# 高密度脂蛋白胆固醇      float64
# 体检天数             int64
# dtype: object

# %%
test.dtypes
# Out:
# *r-谷氨酰基转换酶     float64
# *丙氨酸氨基转换酶      float64
# *天门冬氨酸氨基转换酶    float64
# *总蛋白           float64
# *球蛋白           float64
# *碱性磷酸酶         float64
# id               int64
# 中性粒细胞%         float64
# 低密度脂蛋白胆固醇      float64
# 单核细胞%          float64
# 嗜碱细胞%          float64
# 嗜酸细胞%          float64
# 尿素             float64
# 尿酸             float64
# 年龄               int64
# 性别               int64
# 总胆固醇           float64
# 淋巴细胞%          float64
# 甘油三酯           float64
# 白球比例           float64
# 白细胞计数          float64
# 白蛋白            float64
# 红细胞体积分布宽度      float64
# 红细胞压积          float64
# 红细胞平均体积        float64
# 红细胞平均血红蛋白浓度    float64
# 红细胞平均血红蛋白量     float64
# 红细胞计数          float64
# 肌酐             float64
# 血小板体积分布宽度      float64
# 血小板平均体积        float64
# 血小板比积          float64
# 血小板计数          float64
# 血糖             float64
# 血红蛋白           float64
# 高密度脂蛋白胆固醇      float64
# 体检天数             int64
# dtype: object

# %%
train.describe()
# Out:
#         *r-谷氨酰基转换酶    *丙氨酸氨基转换酶  *天门冬氨酸氨基转换酶         *总蛋白         *球蛋白  \
# count  5642.000000  5642.000000  5642.000000  5642.000000  5642.000000
# mean     38.808367    27.638066    26.802256    76.783911    30.953595
# std      36.105108    20.015352    12.005742     3.555027     3.156575
# min       6.360000     0.120000    10.040000    57.320000     7.060000
# 25%      19.820000    16.760000    21.212500    74.880000    29.240000
# 50%      33.735000    26.455000    26.555000    76.830267    30.971663
# 75%      38.752624    28.432500    27.500000    78.567500    32.430000
# max     736.990000   498.890000   434.950000   100.410000    66.180000
#
#             *碱性磷酸酶           id       中性粒细胞%    低密度脂蛋白胆固醇        单核细胞%  \
# count  5642.000000  5642.000000  5642.000000  5642.000000  5642.000000
# mean     87.500027  2866.184155    56.718526     3.366349     6.856740
# std      22.688061  1655.555649     7.788870     0.761582     1.565359
# ...

# %%
test.describe()
# Out:
#         *r-谷氨酰基转换酶    *丙氨酸氨基转换酶  *天门冬氨酸氨基转换酶         *总蛋白         *球蛋白  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     38.438125    27.302496    26.714812    77.091809    31.073608
# std      40.606809    18.528673     9.951247     3.673501     3.181138
# min       7.260000     6.690000    13.110000    64.130000    20.240000
# 25%      18.920000    16.437500    21.200000    75.027500    29.285000
# 50%      31.710000    24.785000    25.715000    76.830267    30.971663
# 75%      38.752624    28.540000    27.575000    79.167500    32.552500
# max     626.890000   171.890000    98.930000    95.340000    49.860000
#
#             *碱性磷酸酶           id       中性粒细胞%    低密度脂蛋白胆固醇        单核细胞%  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     87.926874  6248.701000    56.854595     3.448628     6.781227
# std      22.994476   299.619678     8.098507     0.814220     1.501410
# ...

# %%
label = train['血糖']
train.drop(['id','血糖'],axis=1,inplace=True)
# Out:
# /Users/alan/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5642 entries, 0 to 5641
# Data columns (total 35 columns):
# *r-谷氨酰基转换酶     5642 non-null float64
# *丙氨酸氨基转换酶      5642 non-null float64
# *天门冬氨酸氨基转换酶    5642 non-null float64
# *总蛋白           5642 non-null float64
# *球蛋白           5642 non-null float64
# *碱性磷酸酶         5642 non-null float64
# 中性粒细胞%         5642 non-null float64
# 低密度脂蛋白胆固醇      5642 non-null float64
# 单核细胞%          5642 non-null float64
# 嗜碱细胞%          5642 non-null float64
# 嗜酸细胞%          5642 non-null float64
# 尿素             5642 non-null float64
# 尿酸             5642 non-null float64
# 年龄             5642 non-null int64
# 性别             5642 non-null int64
# 总胆固醇           5642 non-null float64
# 淋巴细胞%          5642 non-null float64
# 甘油三酯           5642 non-null float64
# 白球比例           5642 non-null float64
# 白细胞计数          5642 non-null float64
# 白蛋白            5642 non-null float64
# 红细胞体积分布宽度      5642 non-null float64
# ...

# %%
from xgboost import XGBRegressor
from xgboost import plot_importance
import xgboost as xgb

plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号
plt.rcParams["figure.figsize"] = [16,9]  #设置图形大小

#模型参数设置
alg = xgb.XGBRegressor(seed=1000)
alg.fit(train, label, verbose=True)
predictor = train.columns
result=alg.predict(test[predictor])
result
#保留三位小数
results = []
for res in result:
    res = ('%.3f' % res)
    results.append(res)
predictions = pd.DataFrame({'血糖':results})
predictions
# Out:
#         血糖
# 0    6.055
# 1    5.943
# 2    5.324
# 3    6.766
# 4    5.312
# 5    5.570
# 6    5.291
# 7    5.498
# 8    5.987
# 9    6.107
# 10   4.869
# 11   5.559
# 12   6.245
# 13   5.771
# 14   6.373
# 15   5.008
# 16   5.326
# 17   6.195
# 18   5.006
# 19   6.430
# 20   5.082
# 21   5.512
# 22   6.324
# 23   6.373
# 24   5.910
# 25   5.375
# 26   5.236
# 27   6.201
# 28   5.450
# 29   5.556
# ..     ...
# 970  6.180
# 971  6.993
# 972  6.492
# 973  7.188
# 974  5.589
# 975  6.061
# 976  5.962
# 977  5.579
# 978  5.607
# 979  4.954
# 980  6.188
# 981  5.041
# 982  5.952
# 983  6.481
# 984  6.632
# 985  5.844
# 986  5.436
# 987  6.081
# 988  6.138
# 989  6.154
# 990  5.938
# 991  5.419
# 992  5.296
# 993  7.558
# 994  7.014
# 995  5.358
# 996  6.590
# 997  6.986
# 998  5.100
# 999  5.633
#
# [1000 rows x 1 columns]

# %%
#可视化特征重要性
plot_importance(alg)
plt.show()

# %%
#用训练数据对模型进行打分
from sklearn import metrics
pred_train = alg.predict(train)
metrics.r2_score(label.values,pred_train)
# Out:
# 0.46777900120463711

# %%
#获取参数
xgb_param = alg.get_params()  #等价函数alg.get_xgb_params()
xgb_param
# Out:
# {'base_score': 0.5,
#  'colsample_bylevel': 1,
#  'colsample_bytree': 1,
#  'gamma': 0,
#  'learning_rate': 0.1,
#  'max_delta_step': 0,
#  'max_depth': 3,
#  'min_child_weight': 1,
#  'missing': None,
#  'n_estimators': 100,
#  'nthread': -1,
#  'objective': 'reg:linear',
#  'reg_alpha': 0,
#  'reg_lambda': 1,
#  'scale_pos_weight': 1,
#  'seed': 1000,
#  'silent': True,
#  'subsample': 1}

# %%
#调参
from sklearn import model_selection, metrics
from sklearn.model_selection import GridSearchCV
#定义函数评价模型好坏的
# def modelfit(alg,x_train,y_train,useTrainCV=True, cv_folds=5, early_stopping_rounds=50):
#     if useTrainCV:
#         alg.fit(x_train,y_train,eval_metric='rmse')  #建模
#         train_pred = alg.predict(x_train) #对训练集进行预测
#         r2_score = metrics.r2_score(y_train.values,train_pred)
#         print('现在模型评分为：%.4f' % r2_score)
# Out:
# 现在模型评分为：0.4678

# %%
predictors = train.columns #特征变量
predictors
# Out:
# Index(['*r-谷氨酰基转换酶', '*丙氨酸氨基转换酶', '*天门冬氨酸氨基转换酶', '*总蛋白', '*球蛋白', '*碱性磷酸酶',
#        '中性粒细胞%', '低密度脂蛋白胆固醇', '单核细胞%', '嗜碱细胞%', '嗜酸细胞%', '尿素', '尿酸', '年龄',
#        '性别', '总胆固醇', '淋巴细胞%', '甘油三酯', '白球比例', '白细胞计数', '白蛋白', '红细胞体积分布宽度',
#        '红细胞压积', '红细胞平均体积', '红细胞平均血红蛋白浓度', '红细胞平均血红蛋白量', '红细胞计数', '肌酐',
#        '血小板体积分布宽度', '血小板平均体积', '血小板比积', '血小板计数', '血红蛋白', '高密度脂蛋白胆固醇', '体检天数'],
#       dtype='object')

# %%
#定义函数来评价模型
from sklearn.metrics import mean_squared_error, r2_score
def modelfit(alg, train, test, useTrainCV=True, cv_folds=5, early_stopping_rounds=50):
    if useTrainCV:
        xgb_param = alg.get_xgb_params()
        xgtrain = xgb.DMatrix(train.values, label=label.values)
        xgtest = xgb.DMatrix(test[predictors].values)
        cvresult = xgb.cv(xgb_param, xgtrain, num_boost_round=alg.get_params()['n_estimators'], nfold=cv_folds,metrics='rmse', early_stopping_rounds=early_stopping_rounds)
        new_estimators=cvresult.shape[0]
        print ('当前弱分类器个数为：%d' % new_estimators)
        alg.set_params(n_estimators=new_estimators)
    
    #Fit the algorithm on the data
    alg.fit(train, label, eval_metric='rmse')
    train_pred = alg.predict(train) #对训练集进行预测
    r2_score = metrics.r2_score(label.values,train_pred)
    print('R^2分数为：%.4f' % r2_score)
    mse = metrics.mean_squared_error(label.values,train_pred)
    print('均方误差分数为：%.4f' % mse)
    plot_importance(alg)
    plt.show()

# %%
#先按照经验值初始化参数值
xgb1 = XGBRegressor(
             base_score = 0.5,
             colsample_bylevel = 0.7,
             colsample_bytree = 1,
             gamma = 0,
             learning_rate = 0.1,
             max_delta_step = 0,
             max_depth = 23,
             min_child_weight = 1,
             missing = None,
             n_estimators = 56,
             nthread = -1,
             objective = 'reg:linear',
             reg_alpha = 0,
             reg_lambda = 1,
             scale_pos_weight = 1,
             seed = 1440,
             silent = True,
             subsample = 0.85)
modelfit(xgb1,train,test)
# Out:
# 最佳弱分类器个数为：56
# R^2分数为：0.9949
# 均方误差分数为：0.0122

# %%
params1 = {
    'max_depth' : range(11,30,2),
    'min_child_weight' : range(1,6,2),
}
gsearch1 = GridSearchCV(
estimator= XGBRegressor(
             base_score = 0.5,
             colsample_bylevel = 0.7,
             colsample_bytree = 1,
             gamma = 0,
             learning_rate = 0.1,
             max_delta_step = 0,
             max_depth = 23,
             min_child_weight = 1,
             missing = None,
             n_estimators = 56,
             nthread = -1,
             objective = 'reg:linear',
             reg_alpha = 0,
             reg_lambda = 1,
             scale_pos_weight = 1,
             seed = 1440,
             silent = True,
             subsample = 0.85
    ),
    param_grid = params1,
    scoring = 'r2',
    cv = 5
)
gsearch1.fit(train,label)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=XGBRegressor(base_score=0.5, colsample_bylevel=0.7, colsample_bytree=1,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=23,
#        min_child_weight=1, missing=None, n_estimators=56, nthread=-1,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=1440, silent=True, subsample=0.85),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'max_depth': range(11, 30, 2), 'min_child_weight': range(1, 6, 2)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='r2', verbose=0)

# %%
gsearch1.grid_scores_, gsearch1.best_params_, gsearch1.best_score_
# Out:
# /Users/alan/anaconda/lib/python3.5/site-packages/sklearn/model_selection/_search.py:747: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# ([mean: 0.13258, std: 0.03988, params: {'max_depth': 11, 'min_child_weight': 1},
#   mean: 0.12148, std: 0.04928, params: {'max_depth': 11, 'min_child_weight': 3},
#   mean: 0.14421, std: 0.06375, params: {'max_depth': 11, 'min_child_weight': 5},
#   mean: 0.13196, std: 0.04477, params: {'max_depth': 13, 'min_child_weight': 1},
#   mean: 0.12979, std: 0.04622, params: {'max_depth': 13, 'min_child_weight': 3},
#   mean: 0.13190, std: 0.05448, params: {'max_depth': 13, 'min_child_weight': 5},
#   mean: 0.13309, std: 0.04602, params: {'max_depth': 15, 'min_child_weight': 1},
#   mean: 0.12294, std: 0.04937, params: {'max_depth': 15, 'min_child_weight': 3},
# ...

# %%
params2 = {
    'max_depth' : [20,21,22],
    'min_child_weight' : [4,5,6],
}
gsearch2 = GridSearchCV(
estimator= XGBRegressor(
             base_score = 0.5,
             colsample_bylevel = 0.7,
             colsample_bytree = 1,
             gamma = 0,
             learning_rate = 0.1,
             max_delta_step = 0,
             max_depth = 23,
             min_child_weight = 1,
             missing = None,
             n_estimators = 56,
             nthread = -1,
             objective = 'reg:linear',
             reg_alpha = 0,
             reg_lambda = 1,
             scale_pos_weight = 1,
             seed = 1440,
             silent = True,
             subsample = 0.85
    ),
    param_grid = params2,
    scoring = 'r2',
    cv = 5
)
gsearch2.fit(train,label)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=XGBRegressor(base_score=0.5, colsample_bylevel=0.7, colsample_bytree=1,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=23,
#        min_child_weight=1, missing=None, n_estimators=56, nthread=-1,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=1440, silent=True, subsample=0.85),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'max_depth': [20, 21, 22], 'min_child_weight': [4, 5, 6]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='r2', verbose=0)

# %%
gsearch2.grid_scores_, gsearch1.best_params_, gsearch1.best_score_
# Out:
# /Users/alan/anaconda/lib/python3.5/site-packages/sklearn/model_selection/_search.py:747: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# ([mean: 0.13343, std: 0.04924, params: {'max_depth': 20, 'min_child_weight': 4},
#   mean: 0.13178, std: 0.05731, params: {'max_depth': 20, 'min_child_weight': 5},
#   mean: 0.14575, std: 0.04453, params: {'max_depth': 20, 'min_child_weight': 6},
#   mean: 0.13396, std: 0.05121, params: {'max_depth': 21, 'min_child_weight': 4},
#   mean: 0.15089, std: 0.05802, params: {'max_depth': 21, 'min_child_weight': 5},
#   mean: 0.13904, std: 0.03991, params: {'max_depth': 21, 'min_child_weight': 6},
#   mean: 0.12964, std: 0.04864, params: {'max_depth': 22, 'min_child_weight': 4},
#   mean: 0.13229, std: 0.05982, params: {'max_depth': 22, 'min_child_weight': 5},
# ...

# %%
params3 = {
   'gamma':[i/10.0 for i in range(0,5)]
}
gsearch3 = GridSearchCV(
estimator= XGBRegressor(
             base_score = 0.5,
             colsample_bylevel = 0.7,
             colsample_bytree = 1,
             gamma = 0,
             learning_rate = 0.1,
             max_delta_step = 0,
             max_depth = 21,
             min_child_weight = 5,
             missing = None,
             n_estimators = 56,
             nthread = -1,
             objective = 'reg:linear',
             reg_alpha = 0,
             reg_lambda = 1,
             scale_pos_weight = 1,
             seed = 1440,
             silent = True,
             subsample = 0.85
    ),
    param_grid = params3,
    scoring = 'r2',
    cv = 5
)
gsearch3.fit(train,label)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=XGBRegressor(base_score=0.5, colsample_bylevel=0.7, colsample_bytree=1,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=21,
#        min_child_weight=5, missing=None, n_estimators=56, nthread=-1,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=1440, silent=True, subsample=0.85),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'gamma': [0.0, 0.1, 0.2, 0.3, 0.4]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='r2', verbose=0)

# %%
gsearch3.grid_scores_, gsearch1.best_params_, gsearch1.best_score_
# Out:
# /Users/alan/anaconda/lib/python3.5/site-packages/sklearn/model_selection/_search.py:747: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# ([mean: 0.15089, std: 0.05802, params: {'gamma': 0.0},
#   mean: 0.14535, std: 0.05865, params: {'gamma': 0.1},
#   mean: 0.13856, std: 0.05351, params: {'gamma': 0.2},
#   mean: 0.13223, std: 0.06066, params: {'gamma': 0.3},
#   mean: 0.12926, std: 0.06380, params: {'gamma': 0.4}],
#  {'max_depth': 21, 'min_child_weight': 5},
#  0.1508912337839613)

# %%
params4 = {
    'subsample':[i/10.0 for i in range(1,10,2)],
    'colsample_bytree':[i/10.0 for i in range(1,10,2)]
}
gsearch4 = GridSearchCV(
estimator= XGBRegressor(
             base_score = 0.5,
             colsample_bylevel = 0.7,
             colsample_bytree = 1,
             gamma = 0,
             learning_rate = 0.1,
             max_delta_step = 0,
             max_depth = 21,
             min_child_weight = 5,
             missing = None,
             n_estimators = 56,
             nthread = -1,
             objective = 'reg:linear',
             reg_alpha = 0,
             reg_lambda = 1,
             scale_pos_weight = 1,
             seed = 1440,
             silent = True,
             subsample = 0.85
    ),
    param_grid = params4,
    scoring = 'r2',
    cv = 5
)
gsearch4.fit(train,label)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=XGBRegressor(base_score=0.5, colsample_bylevel=0.7, colsample_bytree=1,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=21,
#        min_child_weight=5, missing=None, n_estimators=56, nthread=-1,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=1440, silent=True, subsample=0.85),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'colsample_bytree': [0.1, 0.3, 0.5, 0.7, 0.9], 'subsample': [0.1, 0.3, 0.5, 0.7, 0.9]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='r2', verbose=0)

# %%
gsearch4.grid_scores_, gsearch1.best_params_, gsearch1.best_score_
# Out:
# /Users/alan/anaconda/lib/python3.5/site-packages/sklearn/model_selection/_search.py:747: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# ([mean: 0.01972, std: 0.02918, params: {'colsample_bytree': 0.1, 'subsample': 0.1},
#   mean: 0.06850, std: 0.02096, params: {'colsample_bytree': 0.1, 'subsample': 0.3},
#   mean: 0.06518, std: 0.01535, params: {'colsample_bytree': 0.1, 'subsample': 0.5},
#   mean: 0.05525, std: 0.02410, params: {'colsample_bytree': 0.1, 'subsample': 0.7},
#   mean: 0.07148, std: 0.03094, params: {'colsample_bytree': 0.1, 'subsample': 0.9},
#   mean: 0.06174, std: 0.04555, params: {'colsample_bytree': 0.3, 'subsample': 0.1},
#   mean: 0.09310, std: 0.03116, params: {'colsample_bytree': 0.3, 'subsample': 0.3},
#   mean: 0.13478, std: 0.03224, params: {'colsample_bytree': 0.3, 'subsample': 0.5},
# ...

# %%
xgb2 = XGBRegressor(
             base_score = 0.5,
             colsample_bylevel = 0.7,
             colsample_bytree = 0.9,
             gamma = 0,
             learning_rate = 0.1,
             max_delta_step = 0,
             max_depth = 21,
             min_child_weight = 5,
             missing = None,
             n_estimators = 56,
             nthread = -1,
             objective = 'reg:linear',
             reg_alpha = 0,
             reg_lambda = 1,
             scale_pos_weight = 1,
             seed = 1440,
             silent = True,
             subsample = 0.9)
modelfit(xgb2,train,test)
# Out:
# 56
# 现在模型评分为：0.9569

# %%
xgb3 = xgb.XGBRegressor(
             base_score = 0.5,
             colsample_bylevel = 0.7,
             colsample_bytree = 0.9,
             gamma = 0,
             learning_rate = 0.1,
             max_delta_step = 0,
             max_depth = 23,
             min_child_weight = 5,
             missing = None,
             n_estimators = 56,
             nthread = -1,
             objective = 'reg:linear',
             reg_alpha = 0,
             reg_lambda = 1,
             scale_pos_weight = 1,
             seed = 1440,
             silent = True,
             subsample = 0.9)
modelfit(xgb3,train,test)
# Out:
# 56
# 现在模型评分为：0.9596

# %%
xgb4 = XGBRegressor(
             base_score = 0.5,
             colsample_bylevel = 0.7,
             colsample_bytree = 1,
             gamma = 0,
             learning_rate = 0.1,
             max_delta_step = 0,
             max_depth = 23,
             min_child_weight = 1,
             missing = None,
             n_estimators = 56,
             nthread = -1,
             objective = 'reg:linear',
             reg_alpha = 0,
             reg_lambda = 1,
             scale_pos_weight = 1,
             seed = 1440,
             silent = True,
             subsample = 0.85)
modelfit(xgb4,train,test)
# Out:
# 56
# 决定系数回归分数为：0.9949
# 均方误差分数为：0.0122

# %%
xgb5 = XGBRegressor(
             base_score = 0.5,
             colsample_bylevel = 0.7,
             colsample_bytree = 0.9,
             gamma = 0,
             learning_rate = 0.1,
             max_delta_step = 0,
             max_depth = 23,
             min_child_weight = 1,
             missing = None,
             n_estimators = 56,
             nthread = -1,
             objective = 'reg:linear',
             reg_alpha = 0,
             reg_lambda = 1,
             scale_pos_weight = 1,
             seed = 1440,
             silent = True,
             subsample = 0.9)
modelfit(xgb5,train,test)
# Out:
# 最佳弱分类器个数为：56
# R^2分数为：0.9957
# 均方误差分数为：0.0103

# %%
xgb6 = XGBRegressor(
             base_score = 0.5,
             colsample_bylevel = 0.7,
             colsample_bytree = 0.9,
             gamma = 0,
             learning_rate = 0.1,
             max_delta_step = 0,
             max_depth = 23,
             min_child_weight = 1,
             missing = None,
             n_estimators = 100,
             nthread = -1,
             objective = 'reg:linear',
             reg_alpha = 0,
             reg_lambda = 1,
             scale_pos_weight = 1,
             seed = 1440,
             silent = True,
             subsample = 0.9)
modelfit(xgb6,train,test)
# Out:
# 当前弱分类器个数为：100
# R^2分数为：0.9999
# 均方误差分数为：0.0001

# %%
df1 = pd.DataFrame({'train_predict':xgb6.predict(train)})
df2 = pd.DataFrame({'train_label':label})
pd.concat([df1,df2],axis=1,ignore_index=True)  #横向合并为一个df，索引重排序
# Out:
#               0      1
# 0      6.056950   6.06
# 1      5.389965   5.39
# 2      5.588793   5.59
# 3      4.301040   4.30
# 4      5.418380   5.42
# 5      5.969906   5.97
# 6      5.108857   5.11
# 7      5.940366   5.94
# 8      5.664845   5.66
# 9      5.478559   5.48
# 10     4.443994   4.44
# 11     5.481425   5.48
# 12     5.319088   5.32
# 13     5.080786   5.08
# 14     4.630639   4.63
# 15     4.920949   4.92
# 16     7.077589   7.08
# 17     4.661160   4.66
# 18     6.568773   6.58
# 19     4.303173   4.29
# 20     4.552754   4.55
# 21     5.159719   5.16
# 22     5.131194   5.13
# 23     4.376172   4.37
# 24     5.169149   5.17
# 25     4.642925   4.64
# 26     5.818352   5.82
# 27     6.287521   6.29
# 28     5.100546   5.10
# 29     5.410429   5.41
# ...         ...    ...
# 5612   5.320629   5.32
# 5613   5.628659   5.63
# 5614   4.858444   4.84
# 5615   5.440348   5.44
# 5616   4.789019   4.79
# 5617   4.824795   4.82
# 5618   5.251224   5.25
# 5619   4.712584   4.71
# ...

# %%
#模型参数设置
def pred_result(alg):
    alg.fit(train, label, verbose=True)
    predictor = train.columns
    result=alg.predict(test[predictor])
#保留三位小数
    results = []
    for res in result:
        res = ('%.3f' % res)
        results.append(res)
    predictions = pd.DataFrame({'血糖':results})
    return predictions

# %%
predictions = pred_result(xgb6)

# %%
#expoort data to csv file不要列名,行名
predictions.to_csv('/Users/alan/Downloads/github/kaggle/tc_jzyl/submit.csv',encoding = 'utf-8',index=False,header=False)

# %%
len(train.columns)
# Out:
# 35
